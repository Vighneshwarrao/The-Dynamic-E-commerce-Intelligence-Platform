# %%
import pandas as pd

# %%
df=pd.read_csv('../datasets/olist_master_dataset.csv')
df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date  order_item_id  \
# 0                    2017-10-18              1
# 1                    2018-08-13              1
# 2                    2018-09-04              1
# 3                    2017-12-15              1
# 4                    2018-02-26              1
#
#                          product_id  ... customer_state total_payment_value  \
# 0  87285b34884572647811a353c7ac498a  ...             SP               38.71
# 1  595fac2a385ac33a80bd5114aec74eb8  ...             BA              141.46
# 2  aa4383b373c6aca5d8797843e5594415  ...             GO              179.12
# 3  d0b61bfb1de832b15ba9d266ca96e5b0  ...             RN               72.20
# 4  65266b2da20d04dbe00c5c2d3bb7859e  ...             SP               28.62
#
#    payment_installments  payments_method_count primary_payment_type  \
# 0                   3.0                    2.0          credit_card
# 1                   1.0                    1.0               boleto
# 2                   3.0                    1.0          credit_card
# 3                   1.0                    1.0          credit_card
# 4                   1.0                    1.0          credit_card
#
#    review_score review_comment_title  \
# 0           4.0                  NaN
# 1           4.0     Muito boa a loja
# 2           5.0                  NaN
# 3           5.0                  NaN
# 4           5.0                  NaN
#
#                               review_comment_message  product_category  \
# 0  Não testei o produto ainda, mas ele veio corre...        housewares
# 1                               Muito bom o produto.         perfumery
# 2                                                NaN              auto
# 3  O produto foi exatamente o que eu esperava e e...          pet_shop
# 4                                                NaN        stationery
#
#    is_delivered
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
#
# [5 rows x 27 columns]

# %%
df.shape
# Out:
# (113314, 27)

# %%
reviews=df[['review_score','review_comment_title','review_comment_message']]

# %%
reviews.isna().sum()
# Out:
# review_score                  0
# review_comment_title      99880
# review_comment_message    65672
# dtype: int64

# %%
reviews['review_comment_title']=reviews['review_comment_title'].fillna("")
reviews['review_comment_message']=reviews['review_comment_message'].fillna("")
# Out:
# C:\Users\vighn\AppData\Local\Temp\ipykernel_2312\599396796.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reviews['review_comment_title']=reviews['review_comment_title'].fillna("")
# C:\Users\vighn\AppData\Local\Temp\ipykernel_2312\599396796.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reviews['review_comment_message']=reviews['review_comment_message'].fillna("")

# %%
reviews['review']=reviews['review_comment_title']+" "+reviews['review_comment_message']
# Out:
# C:\Users\vighn\AppData\Local\Temp\ipykernel_2312\3334092743.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reviews['review']=reviews['review_comment_title']+" "+reviews['review_comment_message']

# %%
reviews[reviews['review']==""]
# Out:
# Empty DataFrame
# Columns: [review_score, review_comment_title, review_comment_message, review]
# Index: []
